# %%
3 + 4
# Out:
# 7

# %%
b = 9
print(type(b))
print(a + b)
# Out:
# <class 'int'>
# 18

# %%
a = float(input("Enter 1'st number:"))
b = float(input('Enter 2nd number:'))
print('addition is:', a+b)
# Out:
# Enter 1'st number: 4.5
# Enter 2nd number: 6.9
# addition is: 11.4
